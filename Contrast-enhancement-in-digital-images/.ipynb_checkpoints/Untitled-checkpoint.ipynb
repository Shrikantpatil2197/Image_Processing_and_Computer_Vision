# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('input_0.png')
print(img.shape)
plt.imshow(img,'gray')
plt.show()

imagedata = np.float64(img)
print(imagedata.shape)
print(np.size(imagedata)/3)
print(np.size(imagedata[0]))
# Out:
# (221, 329, 3)
# (221, 329, 3)
# 72709.0
# 987
